# %%
import tensorflow as tf
# %matplotlib inline
import matplotlib.pylab as plt
import numpy as np

# %% [markdown]
# # taks: classify euro coins
# * data was downloaded using googleimagesdownload
# * search term was "denomination" + "coin/Münze/..." + "year number"

# %% [markdown]
# # define data generator

# %%
train_image_generator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.1,
    height_shift_range=0.1,
    brightness_range=(0.9, 1.1),
    horizontal_flip=True,
    vertical_flip=True
)

# %% [markdown]
# # search for training data

# %%
train_dir = "./data"
IMG_HEIGHT, IMG_WIDTH = 224, 224
batch_size = 32

train_data_gen = train_image_generator.flow_from_directory(batch_size=batch_size,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_HEIGHT, IMG_WIDTH))
# Out:
# Found 1271 images belonging to 8 classes.

# %% [markdown]
# # found classes

# %%
print(train_data_gen.class_indices)
# Out:
# {'10_cent': 0, '1_cent': 1, '1_euro': 2, '20_cent': 3, '2_cent': 4, '2_euro': 5, '50_cent': 6, '5_cent': 7}

# %% [markdown]
# # display samples from training set
# note: data set is not cleaned at all

# %%
sample_training_images, labels = next(train_data_gen)
class_label = {v:k for k,v in train_data_gen.class_indices.items()}
fig, axes = plt.subplots(8, 4, figsize=(20,20))
axes = axes.flatten()
for img, label, ax in zip(sample_training_images, labels, axes):
    ax.set_title(class_label[np.argmax(label)])
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()

# %% [markdown]
# # use pre-trained model

# %%
base_model = tf.keras.applications.resnet_v2.ResNet50V2(
        include_top=False,
        pooling='max',
        input_shape=(IMG_HEIGHT, IMG_WIDTH, 3),
        weights='imagenet')

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.Dense(512, 'relu'),
    tf.keras.layers.Dense(256, 'relu'),
    tf.keras.layers.Dense(train_data_gen.num_classes, 'softmax')
])
    
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50v2 (Functional)      (None, 2048)              23564800
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 2056
# =================================================================
# Total params: 24,747,272
# Trainable params: 24,701,832
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### utility function that will skip batches if there is a broken image in it

# %%
def skip_broken_images(gen):
    while True:
        try:
            data, labels = next(gen)
            yield data, labels
        except GeneratorExit:
            break
        except:
            pass

# %% [markdown]
# ### snapshot callback

# %%
snapshot_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath="./snapshots",
    verbose=1)

# %% [markdown]
# # train only the fully connected layers

# %%
for layer in base_model.layers:
    layer.trainable = False
    
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

history = model.fit(
    skip_broken_images(train_data_gen),
    steps_per_epoch=2, #use way more steps here: number of samples / batch size
    epochs=3, #use way more or use EarlyStopping callback
    callbacks=[snapshot_callback]
)
# Out:
# Epoch 1/3
# 2/2 [==============================] - 8s 2s/step - loss: 14.3093 - categorical_accuracy: 0.1458
#
# Epoch 00001: saving model to ./snapshots
# /home/alessio/prj/hagenberg/new/venv/lib/python3.7/site-packages/PIL/TiffImagePlugin.py:772: UserWarning: Possibly corrupt EXIF data.  Expecting to read 9 bytes but only got 8. Skipping tag 33432
#   "Possibly corrupt EXIF data.  "
# INFO:tensorflow:Assets written to: ./snapshots/assets
# Epoch 2/3
# 2/2 [==============================] - 4s 2s/step - loss: 15.4018 - categorical_accuracy: 0.0938
#
# Epoch 00002: saving model to ./snapshots
# INFO:tensorflow:Assets written to: ./snapshots/assets
# Epoch 3/3
# 2/2 [==============================] - 4s 2s/step - loss: 8.3418 - categorical_accuracy: 0.2500
# /home/alessio/prj/hagenberg/new/venv/lib/python3.7/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# Epoch 00003: saving model to ./snapshots
# INFO:tensorflow:Assets written to: ./snapshots/assets

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# # train complete network

# %%
for layer in base_model.layers:
    layer.trainable = True
    
    
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])    

history = model.fit(
    skip_broken_images(train_data_gen),
    steps_per_epoch=2, #use way more steps here: number of samples / batch size
    epochs=3, #use way more or use EarlyStopping callback
    callbacks=[snapshot_callback]
)
# Out:
# Epoch 1/3
# 2/2 [==============================] - 20s 8s/step - loss: 10.3278 - categorical_accuracy: 0.1562
#
# Epoch 00001: saving model to ./snapshots
# INFO:tensorflow:Assets written to: ./snapshots/assets
# Epoch 2/3
# /home/alessio/prj/hagenberg/new/venv/lib/python3.7/site-packages/PIL/Image.py:963: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 2/2 [==============================] - 13s 7s/step - loss: 10.2199 - categorical_accuracy: 0.1042
#
# Epoch 00002: saving model to ./snapshots
# INFO:tensorflow:Assets written to: ./snapshots/assets
# Epoch 3/3
# 2/2 [==============================] - 15s 8s/step - loss: 3.0685 - categorical_accuracy: 0.1458
#
# Epoch 00003: saving model to ./snapshots
# INFO:tensorflow:Assets written to: ./snapshots/assets

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# # save final model

# %%
model.save('coin_model_resnet_50.h5')
